# %% [markdown]
# #**Airline Satisfaction through K-Means Clustering**
#
# **1. Project Objectives | Problem Statements**
#
# 1.1. PO1 | PS1: Segmentation of Airline Data using Unsupervised Machine Learning Clustering Algorithms
#
# 1.2. PO2 | PS2: Identification of Appropriate Number of Segments or Clusters
#
# 1.3. PO3 | PS3: Determination of Segment or Cluster Characteristics
#
# **2. Description of Data**
#
# #### 2.1. Data Source, Shape
#
# 2.1.1. Data Source (https://www.kaggle.com/datasets/teejmahal20/airline-passenger-satisfaction)
#
# 2.1.3. Data Shape (Dimension: Number of Variables-25 | Number of Records-103904 rows × 25 columns)
#
#
# **2.2. Description of Variables**
#
# **2.2.1. Index Variable(s)**
#
# Index Variable(s): ID
#
# **.2.2. Variables or Features having Categories | Categorical Variables or Features (CV)**
#
# **2.2.2.1. Variables or Features having Nominal Categories | Categorical
# Variables or Features - Nominal Type**
#
# **Nominal Categories:**
#
# Gender
#
# Customer Type
#
# Type of Travel
#
# Class
#
# **2.2.2.2. Variables or Features having Ordinal Categories | Categorical Variables or Features - Ordinal Type**
#
# **Ordinal Categories:**
#
# Satisfaction
#
# Inflight wifi service
#
# Departure/Arrival time convenient
#
# Ease of Online booking
#
# Gate location
#
# Food and drink
#
# Online boarding
#
# Seat comfort
#
# Inflight entertainment
#
# On-board service
#
# Leg room service
#
# Baggage handling
#
# Check-in service
#
# Inflight service
#
# Cleanliness
#
# **2.2.3. Non-Categorical Variables or Features
# Non-Categorical Variables or Features:**
#
#
# Age
#
# Flight distance
#
# Departure Delay in Minutes
#
# Arrival Delay in Minutes
#
# **Variable Description:**
#
# **Index Variable:**
#
# ID
#
# **Categorical Variables:**
#
# **Nominal Categories:**
#
# Gender - Gender of the passengers (Female, Male)
#
# Customer Type - The customer type (Loyal customer, disloyal customer)
#
#
# Type of Travel - Purpose of the flight of the passengers (Personal Travel, Business Travel)
#
# Class - Travel class in the plane of the passengers (Business, Eco, Eco Plus)
#
#
# Inflight wifi service - Satisfaction level of the inflight wifi service (0:Not Applicable;1-5)
#
# Departure/Arrival time convenient - Satisfaction level of Departure/Arrival time convenient
#
# Ease of Online booking - Satisfaction level of online booking
#
# Gate location - Satisfaction level of Gate location
#
# Food and drink - Satisfaction level of Food and drink
#
# Online boarding - Satisfaction level of online boarding
#
# Seat comfort - Satisfaction level of Seat comfort
#
# Inflight entertainment - Satisfaction level of inflight entertainment
#
# On-board service - Satisfaction level of On-board service
#
# Leg room service - Satisfaction level of Leg room service
#
# Baggage handling - Satisfaction level of baggage handling
#
# Check-in service - Satisfaction level of Check-in service
#
# Inflight service - Satisfaction level of inflight service
#
# Cleanliness - Satisfaction level of Cleanliness
#
# Satisfaction - Airline satisfaction level(Satisfaction, neutral or dissatisfaction)
#
# **Non-Categorical Variables:**
#
#
# Age - The actual age of the passengers
#
# Flight distance - The flight distance of this journey
#
# Departure Delay in Minutes - Minutes delayed when departure
#
# Arrival Delay in Minutes - Minutes delayed when Arrival
#
#
#
# #### **2.3 Descriptive Statistics: Non-Categorical Variables or Features**
# ##### **2.3.1.1. Measures of Central Tendency**
# - **Mean:**
#    - Age: 39.380466
#
#    - Flight distance: 1189.325202
#
#    - Departure Delay in Minutes: 14.747939
#
#    - Arrival Delay in Minutes: 15.178678
#
# ##### **2.3.2.2. Measures of Dispersion**
# - **Standard Deviation:**
#    - Age: 15.113125
#
#    - Flight distance: 997.297235
#
#    - Departure Delay in Minutes: 38.116737
#
#    - Arrival Delay in Minutes: 38.698682
#
#
# ### **3.1. Data Pre-Processing**
#
# #### **3.1.1. Missing Data Statistics and Treatment**
# - **Variable-wise Missing Data Information:**
#    - Arrival Delay in Minutes  -           310 values missing
#
# - **Record-wise Missing Data Information (Top 5 Records):**
#    - No records with missing data.
#
# #### 3.1.2. Numerical Encoding of Categorical Variables or Features
# - **Ordinal Encoder:**
#    - Used to encode categorical variables into numerical format.
#
# #### 3.1.3. Outlier Statistics and Treatment
# - **Outlier Detection:**
#    - Identified outliers using boxplot visualization.
#
# - **Outlier Treatment:**
#    - Outliers treated by performing normalization using Min-Max Scaler.
#
# #### 3.1.4. Data Transformation and Scaling
# - **Normalization:**
#    - Min-Max Scaling applied to non-categorical variables to bring them within a common scale.
#
# #### 3.1.5. Pre-Processed Dataset
# - **Pre-Processed Categorical Data Subset:**
#    - Encoded categorical data using Ordinal Encoder.
#
# - **Pre-Processed Non-Categorical Data Subset:**
#    - Normalized non-categorical data using Min-Max Scaler.
#
# - **Pre-Processed Dataset:**
#    - Merged pre-processed categorical and non-categorical data subsets.
#
# ### **4. Findings**
#
# #### 4.1 Clustering
# - The model with 2 clusters provides the best separation between clusters, as indicated by the highest silhouette score and the lowest Davies-Bouldin index.
#
# - As the number of clusters increases, the silhouette score decreases, indicating less distinct separation between clusters.
#
# - The Davies-Bouldin index also increases with the number of clusters, suggesting that the clustering quality deteriorates as the number of clusters increases.
#
# - Cluster near the origin represents flights that were on time or had minimal delays for both departure and arrival. The larger this cluster, the more consistent the airline is at operating on schedule.
#
# - Lower left clusters represent flights with delays in both departure and arrival. The distance of the centroid from the origin indicates the severity of the delays. A cluster closer to the axes suggests minor delays, while one further indicates significant delays for both.
#
# 4.2 Time taken and memory usage
# - Time taken by K-Means for k=4: 3.0426 seconds
# - Memory used by K-Means for k=4: 519.45 MB
#
# #### 4.3 Chi-Square Test
#
# The Chi-Square Test of Independence is used to determine whether there is a significant association between two categorical variables. In this case, the test is applied to each pair of a categorical variable and the 'cluster' variable.
#
# - Gender_code: The Chi-Square value is 0.93 with a p-value of 0.82. This indicates that there is no significant association between gender and the clusters.
#
# - Customer Type_code: The Chi-Square value is 1.46 with a p-value of 0.69. Similar to gender, there is no significant association between customer type and the clusters.
#
# - Type of Travel_code: The Chi-Square value is 1.08 with a p-value of 0.78. Again, there is no significant association between the type of travel and the clusters.
#
# - Class_code: The Chi-Square value is 2.38 with a p-value of 0.88. There is no significant association between travel class and the clusters.
#
# - Satisfaction_code: The Chi-Square value is 0.50 with a p-value of 0.92. There is no significant association between satisfaction level and the clusters.
#
# - Other variables: Similar interpretations can be drawn for other variables. None of them show a significant association with the clusters.
#
# #### 4.4 ANOVA
#
# Departure Delay in Minutes and Arrival Delay in Minutes:
#
# - The F-values for both variables are extremely high, indicating significant differences in departure and arrival delays among the clusters.
#
# - The p-values for both variables are 0.0, indicating strong evidence against the null hypothesis that there are no differences in departure and arrival delays among the clusters.
#
# Departure Delay in Minutes_mmnorm and Arrival Delay in Minutes_mmnorm:
#
# - The F-values for both variables are relatively low, suggesting that there are no significant differences in the standardized (min-max normalized) departure and arrival delays among the clusters.
#
# - The p-values for both variables are relatively high, indicating that there is no strong evidence against the null hypothesis that there are no differences in standardized departure and arrival delays among the clusters.
#
# ###**5. Managerial Implications**
#
# - The clustering analysis has segmented airline passengers into different groups based on their characteristics and satisfaction levels. This segmentation can help airlines understand their customer base better and tailor their services to meet the specific needs and preferences of each segment.
#
# - By examining the variables that are most associated with each cluster, airlines can identify the factors that contribute most to passenger satisfaction. This insight can guide decision-making processes aimed at improving overall customer experience.
#
# - Understanding the clusters can help airlines optimize their operations to better serve their customers. For example, clusters with high levels of satisfaction and minimal delays can serve as benchmarks for operational excellence, while clusters with lower satisfaction levels and significant delays can highlight areas for improvement.
#
# - With a clearer understanding of their customer segments, airlines can develop targeted marketing campaigns and personalized service offerings to enhance customer loyalty and satisfaction. By catering to the specific preferences of each segment, airlines can increase customer retention and drive revenue growth.
#
# - The analysis can also inform resource allocation decisions, such as staffing levels, fleet management, and infrastructure investments. Airlines can allocate resources more effectively by prioritizing areas that have the greatest impact on customer satisfaction and segment-specific needs.
#
# - The analysis provides a basis for continuous improvement efforts. By monitoring customer satisfaction levels over time and adjusting strategies accordingly, airlines can maintain competitiveness in the market and ensure long-term success.

# %%
# Required Libraries
import pandas as pd, numpy as np # For Data Manipulation
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder # For Encoding Categorical Data [Nominal | Ordinal]
from sklearn.preprocessing import OneHotEncoder # For Creating Dummy Variables of Categorical Data [Nominal]
from sklearn.impute import SimpleImputer, KNNImputer # For Imputation of Missing Data
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler # For Rescaling Data
from sklearn.model_selection import train_test_split # For Splitting Data into Training & Testing Sets
import pandas as pd, numpy as np # For Data Manipulation
import matplotlib.pyplot as plt, seaborn as sns # For Data Visualization
import scipy.cluster.hierarchy as sch # For Hierarchical Clustering
from sklearn.cluster import AgglomerativeClustering as agclus, KMeans as kmclus # For Agglomerative & K-Means Clustering
from sklearn.metrics import silhouette_score as sscore, davies_bouldin_score as dbscore # For Clustering Model Evaluation

# %%
df=pd.read_csv("airline_satisfaction.csv")
df
# Out:
#         Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0                0   70172    Male     Loyal Customer   13  Personal Travel
# 1                1    5047    Male  disloyal Customer   25  Business travel
# 2                2  110028  Female     Loyal Customer   26  Business travel
# 3                3   24026  Female     Loyal Customer   25  Business travel
# 4                4  119299    Male     Loyal Customer   61  Business travel
# ...            ...     ...     ...                ...  ...              ...
# 103899      103899   94171  Female  disloyal Customer   23  Business travel
# 103900      103900   73097    Male     Loyal Customer   49  Business travel
# 103901      103901   68825    Male  disloyal Customer   30  Business travel
# 103902      103902   54173  Female  disloyal Customer   22  Business travel
# 103903      103903   62567    Male     Loyal Customer   27  Business travel
#
#            Class  Flight Distance  Inflight wifi service  \
# 0       Eco Plus              460                      3
# 1       Business              235                      3
# 2       Business             1142                      2
# 3       Business              562                      2
# 4       Business              214                      3
# ...          ...              ...                    ...
# 103899       Eco              192                      2
# 103900  Business             2347                      4
# 103901  Business             1995                      1
# 103902       Eco             1000                      1
# 103903  Business             1723                      1
#
#         Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                       4  ...                       5
# 1                                       2  ...                       1
# 2                                       2  ...                       5
# 3                                       5  ...                       2
# 4                                       3  ...                       3
# ...                                   ...  ...                     ...
# 103899                                  1  ...                       2
# 103900                                  4  ...                       5
# 103901                                  1  ...                       4
# 103902                                  1  ...                       1
# 103903                                  3  ...                       1
#
#         On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                      4                 3                 4                4
# 1                      1                 5                 3                1
# 2                      4                 3                 4                4
# 3                      2                 5                 3                1
# 4                      3                 4                 4                3
# ...                  ...               ...               ...              ...
# 103899                 3                 1                 4                2
# 103900                 5                 5                 5                5
# 103901                 3                 2                 4                5
# 103902                 4                 5                 1                5
# 103903                 1                 1                 4                4
#
#         Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                      5            5                          25
# 1                      4            1                           1
# 2                      4            5                           0
# 3                      4            2                          11
# 4                      3            3                           0
# ...                  ...          ...                         ...
# 103899                 3            2                           3
# 103900                 5            4                           0
# 103901                 5            4                           7
# 103902                 4            1                           0
# 103903                 3            1                           0
#
#         Arrival Delay in Minutes             satisfaction
# 0                           18.0  neutral or dissatisfied
# 1                            6.0  neutral or dissatisfied
# 2                            0.0                satisfied
# 3                            9.0  neutral or dissatisfied
# 4                            0.0                satisfied
# ...                          ...                      ...
# 103899                       0.0  neutral or dissatisfied
# 103900                       0.0                satisfied
# 103901                      14.0  neutral or dissatisfied
# 103902                       0.0  neutral or dissatisfied
# 103903                       0.0  neutral or dissatisfied
#
# [103904 rows x 25 columns]

# %%
df_cat = df[['Gender', 'Customer Type', 'Type of Travel', 'Class', 'satisfaction',
                         'Inflight wifi service', 'Departure/Arrival time convenient', 'Ease of Online booking',
                         'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
                         'Inflight entertainment', 'On-board service', 'Leg room service',
                         'Baggage handling', 'Checkin service', 'Inflight service', 'Cleanliness']] # Categorical Data [Nominal | Ordinal]
df_noncat = df[['Age', 'Flight Distance', 'Departure Delay in Minutes', 'Arrival Delay in Minutes']] # Non-Categorical Data

# %%
print(df.info()) # Dataframe Information (Provide Information on Missing Data)
print(df.describe())
variable_missing_data = df.isna().sum(); variable_missing_data # Variable-wise Missing Data Information
print(variable_missing_data)
record_missing_data = df.isna().sum(axis=1).sort_values(ascending=False).head(5); record_missing_data # Record-wise Missing Data Information (Top 5)
print(record_missing_data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Unnamed: 0                         103904 non-null  int64
#  1   id                                 103904 non-null  int64
#  2   Gender                             103904 non-null  object
#  3   Customer Type                      103904 non-null  object
#  4   Age                                103904 non-null  int64
#  5   Type of Travel                     103904 non-null  object
#  6   Class                              103904 non-null  object
#  7   Flight Distance                    103904 non-null  int64
#  8   Inflight wifi service              103904 non-null  int64
#  9   Departure/Arrival time convenient  103904 non-null  int64
#  10  Ease of Online booking             103904 non-null  int64
#  11  Gate location                      103904 non-null  int64
#  12  Food and drink                     103904 non-null  int64
#  13  Online boarding                    103904 non-null  int64
#  14  Seat comfort                       103904 non-null  int64
#  15  Inflight entertainment             103904 non-null  int64
#  16  On-board service                   103904 non-null  int64
#  17  Leg room service                   103904 non-null  int64
#  18  Baggage handling                   103904 non-null  int64
#  19  Checkin service                    103904 non-null  int64
#  20  Inflight service                   103904 non-null  int64
#  21  Cleanliness                        103904 non-null  int64
#  22  Departure Delay in Minutes         103904 non-null  int64
#  23  Arrival Delay in Minutes           103594 non-null  float64
#  24  satisfaction                       103904 non-null  object
# dtypes: float64(1), int64(19), object(5)
# memory usage: 19.8+ MB
# None
#           Unnamed: 0             id            Age  Flight Distance  \
# count  103904.000000  103904.000000  103904.000000    103904.000000
# mean    51951.500000   64924.210502      39.379706      1189.448375
# std     29994.645522   37463.812252      15.114964       997.147281
# min         0.000000       1.000000       7.000000        31.000000
# 25%     25975.750000   32533.750000      27.000000       414.000000
# 50%     51951.500000   64856.500000      40.000000       843.000000
# 75%     77927.250000   97368.250000      51.000000      1743.000000
# max    103903.000000  129880.000000      85.000000      4983.000000
#
#        Inflight wifi service  Departure/Arrival time convenient  \
# count          103904.000000                      103904.000000
# mean                2.729683                           3.060296
# std                 1.327829                           1.525075
# min                 0.000000                           0.000000
# 25%                 2.000000                           2.000000
# 50%                 3.000000                           3.000000
# 75%                 4.000000                           4.000000
# max                 5.000000                           5.000000
#
#        Ease of Online booking  Gate location  Food and drink  Online boarding  \
# count           103904.000000  103904.000000   103904.000000    103904.000000
# mean                 2.756901       2.976883        3.202129         3.250375
# std                  1.398929       1.277621        1.329533         1.349509
# min                  0.000000       0.000000        0.000000         0.000000
# 25%                  2.000000       2.000000        2.000000         2.000000
# 50%                  3.000000       3.000000        3.000000         3.000000
# 75%                  4.000000       4.000000        4.000000         4.000000
# max                  5.000000       5.000000        5.000000         5.000000
#
#         Seat comfort  Inflight entertainment  On-board service  \
# count  103904.000000           103904.000000     103904.000000
# mean        3.439396                3.358158          3.382363
# std         1.319088                1.332991          1.288354
# min         0.000000                0.000000          0.000000
# 25%         2.000000                2.000000          2.000000
# 50%         4.000000                4.000000          4.000000
# 75%         5.000000                4.000000          4.000000
# max         5.000000                5.000000          5.000000
#
#        Leg room service  Baggage handling  Checkin service  Inflight service  \
# count     103904.000000     103904.000000    103904.000000     103904.000000
# mean           3.351055          3.631833         3.304290          3.640428
# std            1.315605          1.180903         1.265396          1.175663
# min            0.000000          1.000000         0.000000          0.000000
# 25%            2.000000          3.000000         3.000000          3.000000
# 50%            4.000000          4.000000         3.000000          4.000000
# 75%            4.000000          5.000000         4.000000          5.000000
# max            5.000000          5.000000         5.000000          5.000000
#
#          Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes
# count  103904.000000               103904.000000             103594.000000
# mean        3.286351                   14.815618                 15.178678
# std         1.312273                   38.230901                 38.698682
# min         0.000000                    0.000000                  0.000000
# 25%         2.000000                    0.000000                  0.000000
# 50%         3.000000                    0.000000                  0.000000
# 75%         4.000000                   12.000000                 13.000000
# max         5.000000                 1592.000000               1584.000000
# Unnamed: 0                             0
# id                                     0
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             310
# satisfaction                           0
# dtype: int64
# 18620    1
# 60015    1
# 47368    1
# 94759    1
# 23033    1
# dtype: int64

# %%
# Dataset Used : df_cat

si_cat = SimpleImputer(missing_values=np.nan, strategy='most_frequent') # Strategy = median [When Odd Number of Categories Exists]
si_cat_fit = si_cat.fit_transform(df_cat)
df_cat_mdi = pd.DataFrame(si_cat_fit, columns=df_cat.columns); df_cat_mdi # Missing Categorical Data Imputed Subset
df_cat_mdi.info()

# Impute Missing Non-Categorical Data using Descriptive Statistics : Central Tendency

# Dataset Used : df_noncat

si_noncat = SimpleImputer(missing_values=np.nan, strategy='mean') # Other Strategy : mean | median | most_frequent | constant
si_noncat_fit = si_noncat.fit_transform(df_noncat)
df_noncat_mdi_si = pd.DataFrame(si_noncat_fit, columns=df_noncat.columns); df_noncat_mdi_si # Missing Non-Categorical Data Imputed Subset using Simple Imputer
df_noncat_mdi_si.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 19 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Gender                             103904 non-null  object
#  1   Customer Type                      103904 non-null  object
#  2   Type of Travel                     103904 non-null  object
#  3   Class                              103904 non-null  object
#  4   satisfaction                       103904 non-null  object
#  5   Inflight wifi service              103904 non-null  object
#  6   Departure/Arrival time convenient  103904 non-null  object
#  7   Ease of Online booking             103904 non-null  object
#  8   Gate location                      103904 non-null  object
#  9   Food and drink                     103904 non-null  object
#  10  Online boarding                    103904 non-null  object
#  11  Seat comfort                       103904 non-null  object
#  12  Inflight entertainment             103904 non-null  object
#  13  On-board service                   103904 non-null  object
#  14  Leg room service                   103904 non-null  object
#  15  Baggage handling                   103904 non-null  object
#  16  Checkin service                    103904 non-null  object
#  17  Inflight service                   103904 non-null  object
#  18  Cleanliness                        103904 non-null  object
# dtypes: object(19)
# memory usage: 15.1+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 4 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Age                         103904 non-null  float64
#  1   Flight Distance             103904 non-null  float64
#  2   Departure Delay in Minutes  103904 non-null  float64
#  3   Arrival Delay in Minutes    103904 non-null  float64
# dtypes: float64(4)
# memory usage: 3.2 MB

# %%
df= df.dropna()

# %%
df=df.drop(['Unnamed: 0','id'],axis=1)

# %%
#Numeric Encoding of Categorical Data [Nominal & Ordinal]
df_cat_mdt_code = df_cat_mdi.copy()
oe = OrdinalEncoder()
oe_fit = oe.fit_transform(df_cat_mdt_code)
df_cat_code_oe = pd.DataFrame(oe_fit, columns=['Gender_code', 'Customer Type_code', 'Type of Travel_code', 'Class_code', 'satisfaction_code',
                         'Inflight wifi service_code', 'Departure/Arrival time convenient_code', 'Ease of Online booking_code',
                         'Gate location_code', 'Food and drink_code', 'Online boarding_code', 'Seat comfort_code',
                         'Inflight entertainment_code', 'On-board service_code', 'Leg room service_code',
                         'Baggage handling_code', 'Checkin service_code', 'Inflight service_code', 'Cleanliness_code']); df_cat_code_oe
df_cat_mdt_code_oe = df_cat_mdt_code.join(df_cat_code_oe); df_cat_mdt_code_oe # (Missing Data Treated) Numeric Coded Categorical Dataset using Scikit Learn Ordinal Encoder
df_cat_mdt_code_oe = pd.merge(df_cat_mdt_code, df_cat_code_oe, left_index=True, right_index=True);
df_cat_mdt_code_oe
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 0         Male     Loyal Customer  Personal Travel  Eco Plus
# 1         Male  disloyal Customer  Business travel  Business
# 2       Female     Loyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 4         Male     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103899  Female  disloyal Customer  Business travel       Eco
# 103900    Male     Loyal Customer  Business travel  Business
# 103901    Male  disloyal Customer  Business travel  Business
# 103902  Female  disloyal Customer  Business travel       Eco
# 103903    Male     Loyal Customer  Business travel  Business
#
#                    satisfaction Inflight wifi service  \
# 0       neutral or dissatisfied                     3
# 1       neutral or dissatisfied                     3
# 2                     satisfied                     2
# 3       neutral or dissatisfied                     2
# 4                     satisfied                     3
# ...                         ...                   ...
# 103899  neutral or dissatisfied                     2
# 103900                satisfied                     4
# 103901  neutral or dissatisfied                     1
# 103902  neutral or dissatisfied                     1
# 103903  neutral or dissatisfied                     1
#
#        Departure/Arrival time convenient Ease of Online booking Gate location  \
# 0                                      4                      3             1
# 1                                      2                      3             3
# 2                                      2                      2             2
# 3                                      5                      5             5
# 4                                      3                      3             3
# ...                                  ...                    ...           ...
# 103899                                 1                      2             3
# 103900                                 4                      4             4
# 103901                                 1                      1             3
# 103902                                 1                      1             5
# 103903                                 3                      3             3
#
#        Food and drink  ... Food and drink_code Online boarding_code  \
# 0                   5  ...                 5.0                  3.0
# 1                   1  ...                 1.0                  3.0
# 2                   5  ...                 5.0                  5.0
# 3                   2  ...                 2.0                  2.0
# 4                   4  ...                 4.0                  5.0
# ...               ...  ...                 ...                  ...
# 103899              2  ...                 2.0                  2.0
# 103900              2  ...                 2.0                  4.0
# 103901              4  ...                 4.0                  1.0
# 103902              1  ...                 1.0                  1.0
# 103903              1  ...                 1.0                  1.0
#
#        Seat comfort_code Inflight entertainment_code On-board service_code  \
# 0                    5.0                         5.0                   4.0
# 1                    1.0                         1.0                   1.0
# 2                    5.0                         5.0                   4.0
# 3                    2.0                         2.0                   2.0
# 4                    5.0                         3.0                   3.0
# ...                  ...                         ...                   ...
# 103899               2.0                         2.0                   3.0
# 103900               5.0                         5.0                   5.0
# 103901               5.0                         4.0                   3.0
# 103902               1.0                         1.0                   4.0
# 103903               1.0                         1.0                   1.0
#
#        Leg room service_code Baggage handling_code Checkin service_code  \
# 0                        3.0                   3.0                  4.0
# 1                        5.0                   2.0                  1.0
# 2                        3.0                   3.0                  4.0
# 3                        5.0                   2.0                  1.0
# 4                        4.0                   3.0                  3.0
# ...                      ...                   ...                  ...
# 103899                   1.0                   3.0                  2.0
# 103900                   5.0                   4.0                  5.0
# 103901                   2.0                   3.0                  5.0
# 103902                   5.0                   0.0                  5.0
# 103903                   1.0                   3.0                  4.0
#
#        Inflight service_code  Cleanliness_code
# 0                        5.0               5.0
# 1                        4.0               1.0
# 2                        4.0               5.0
# 3                        4.0               2.0
# 4                        3.0               3.0
# ...                      ...               ...
# 103899                   3.0               2.0
# 103900                   5.0               4.0
# 103901                   5.0               4.0
# 103902                   4.0               1.0
# 103903                   3.0               1.0
#
# [103904 rows x 38 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming df is your DataFrame and contains the columns 'Offers', 'Average Price', and 'Number of Ratings'
df_noncat_mdi_si = df[['Departure Delay in Minutes', 'Arrival Delay in Minutes']]

# Create vertical boxplot for 'Offers'
plt.figure(figsize=(8, 6))
sns.boxplot(y=df_noncat_mdi_si['Departure Delay in Minutes'])
plt.title('Boxplot of Departure Delay in Minutes')
plt.ylabel('Departure Delay in Minutes')
plt.show()

# Create vertical boxplot for 'Average Price'
plt.figure(figsize=(8, 6))
sns.boxplot(y=df_noncat_mdi_si['Arrival Delay in Minutes'])
plt.title('Boxplot of Arrival Delay in Minutes')
plt.ylabel('Arrival Delay in Minutes')
plt.show()

# %%
# 3.2.1. Normalization : Min-Max Scaling
mms = MinMaxScaler()
mms_fit = mms.fit_transform(df_noncat_mdi_si[['Departure Delay in Minutes', 'Arrival Delay in Minutes']])
df_noncat_minmax_norm = pd.DataFrame(mms_fit, columns=['Departure Delay in Minutes_mmnorm', 'Arrival Delay in Minutes_mmnorm']); df_noncat_minmax_norm

#df_noncat_minmax_norm = pd.DataFrame(mms_fit, columns=df_noncat_mdt.columns+'_mmnorm'); df_noncat_minmax_norm
df_noncat_mdt_mmn = df_noncat_mdi_si.join(df_noncat_minmax_norm);  # (Missing Data Treated) Normalized Non-Categorical Dataset using Sikit Learn Min-Max Scaler
#df_noncat_mdt_mmn = pd.merge(df_noncat_mdt, df_noncat_minmax_norm, left_index=True, right_index=True); df_noncat_mdt_mmn

df_noncat_mdt_mmn_si = SimpleImputer(missing_values=np.nan, strategy='mean') # Strategy = median [When Odd Number of Categories Exists]
df_noncat_mdt_mmn_si_fit = df_noncat_mdt_mmn_si.fit_transform(df_noncat_mdt_mmn)
df_noncat_mdt_mmn_mdi = pd.DataFrame(df_noncat_mdt_mmn_si_fit, columns=df_noncat_mdt_mmn.columns); # Missing Categorical Data Imputed Subset
df_noncat_mdt_mmn_mdi.info()

df_noncat_mdt_mmn_mdi
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103594 entries, 0 to 103593
# Data columns (total 4 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Departure Delay in Minutes         103594 non-null  float64
#  1   Arrival Delay in Minutes           103594 non-null  float64
#  2   Departure Delay in Minutes_mmnorm  103594 non-null  float64
#  3   Arrival Delay in Minutes_mmnorm    103594 non-null  float64
# dtypes: float64(4)
# memory usage: 3.2 MB
#         Departure Delay in Minutes  Arrival Delay in Minutes  \
# 0                             25.0                      18.0
# 1                              1.0                       6.0
# 2                              0.0                       0.0
# 3                             11.0                       9.0
# 4                              0.0                       0.0
# ...                            ...                       ...
# 103589                         3.0                       0.0
# 103590                         0.0                       0.0
# 103591                         7.0                      14.0
# 103592                         0.0                       0.0
# 103593                         0.0                       0.0
#
#         Departure Delay in Minutes_mmnorm  Arrival Delay in Minutes_mmnorm
# 0                                0.015704                         0.011364
# 1                                0.000628                         0.003788
# 2                                0.000000                         0.000000
# 3                                0.006910                         0.005682
# 4                                0.000000                         0.000000
# ...                                   ...                              ...
# 103589                           0.009268                         0.009587
# 103590                           0.009268                         0.009587
# 103591                           0.009268                         0.009587
# 103592                           0.009268                         0.009587
# 103593                           0.009268                         0.009587
#
# [103594 rows x 4 columns]

# %%
# Pre-Processed Dataset

# Using Scikit Learn Ordinal Encoder : df_cat_mdt_code_oe [Superior]

# Missing Data Treated & Transformed or Rescaled Non-Categorical Data Subsets

# Using Scikit Learn Standard Scaler : df_noncat_mdt_std [Standardization]


# Pre-Processed Categorical Data Subset
df_cat_ppd = df_cat_mdt_code_oe.copy(); df_cat_ppd # Preferred Data Subset

# Pre-Processed Non-Categorical Data Subset
df_noncat_ppd = df_noncat_mdt_mmn_mdi.copy(); df_noncat_ppd


# Pre-Processed Dataset
df_ppd = df_cat_ppd.join(df_noncat_ppd); df_ppd # Pre-Processed Dataset
df_ppd = pd.merge(df_cat_ppd, df_noncat_ppd, left_index=True, right_index=True); df_ppd
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 0         Male     Loyal Customer  Personal Travel  Eco Plus
# 1         Male  disloyal Customer  Business travel  Business
# 2       Female     Loyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 4         Male     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103589  Female     Loyal Customer  Business travel  Business
# 103590  Female     Loyal Customer  Business travel  Eco Plus
# 103591  Female     Loyal Customer  Personal Travel       Eco
# 103592    Male     Loyal Customer  Business travel  Business
# 103593    Male     Loyal Customer  Personal Travel       Eco
#
#                    satisfaction Inflight wifi service  \
# 0       neutral or dissatisfied                     3
# 1       neutral or dissatisfied                     3
# 2                     satisfied                     2
# 3       neutral or dissatisfied                     2
# 4                     satisfied                     3
# ...                         ...                   ...
# 103589  neutral or dissatisfied                     2
# 103590  neutral or dissatisfied                     3
# 103591  neutral or dissatisfied                     4
# 103592                satisfied                     4
# 103593  neutral or dissatisfied                     3
#
#        Departure/Arrival time convenient Ease of Online booking Gate location  \
# 0                                      4                      3             1
# 1                                      2                      3             3
# 2                                      2                      2             2
# 3                                      5                      5             5
# 4                                      3                      3             3
# ...                                  ...                    ...           ...
# 103589                                 5                      5             5
# 103590                                 1                      2             1
# 103591                                 5                      4             5
# 103592                                 4                      4             4
# 103593                                 5                      3             2
#
#        Food and drink  ... On-board service_code Leg room service_code  \
# 0                   5  ...                   4.0                   3.0
# 1                   1  ...                   1.0                   5.0
# 2                   5  ...                   4.0                   3.0
# 3                   2  ...                   2.0                   5.0
# 4                   4  ...                   3.0                   4.0
# ...               ...  ...                   ...                   ...
# 103589              2  ...                   1.0                   2.0
# 103590              4  ...                   3.0                   3.0
# 103591              2  ...                   4.0                   4.0
# 103592              3  ...                   4.0                   4.0
# 103593              2  ...                   4.0                   3.0
#
#        Baggage handling_code Checkin service_code Inflight service_code  \
# 0                        3.0                  4.0                   5.0
# 1                        2.0                  1.0                   4.0
# 2                        3.0                  4.0                   4.0
# 3                        2.0                  1.0                   4.0
# 4                        3.0                  3.0                   3.0
# ...                      ...                  ...                   ...
# 103589                   2.0                  4.0                   3.0
# 103590                   2.0                  4.0                   3.0
# 103591                   4.0                  5.0                   4.0
# 103592                   1.0                  3.0                   2.0
# 103593                   3.0                  5.0                   4.0
#
#        Cleanliness_code Departure Delay in Minutes Arrival Delay in Minutes  \
# 0                   5.0                       25.0                     18.0
# 1                   1.0                        1.0                      6.0
# 2                   5.0                        0.0                      0.0
# 3                   2.0                       11.0                      9.0
# 4                   3.0                        0.0                      0.0
# ...                 ...                        ...                      ...
# 103589              2.0                        3.0                      0.0
# 103590              4.0                        0.0                      0.0
# 103591              2.0                        7.0                     14.0
# 103592              3.0                        0.0                      0.0
# 103593              2.0                        0.0                      0.0
#
#        Departure Delay in Minutes_mmnorm  Arrival Delay in Minutes_mmnorm
# 0                               0.015704                         0.011364
# 1                               0.000628                         0.003788
# 2                               0.000000                         0.000000
# 3                               0.006910                         0.005682
# 4                               0.000000                         0.000000
# ...                                  ...                              ...
# 103589                          0.009268                         0.009587
# 103590                          0.009268                         0.009587
# 103591                          0.009268                         0.009587
# 103592                          0.009268                         0.009587
# 103593                          0.009268                         0.009587
#
# [103594 rows x 42 columns]

# %%
#K-Means Clustering


# 2.1.1. Determine Value of 'K' in K-Means using Elbow Curve & KMeans-Inertia

'''
KMeans-Inertia : Sum of Squared Distances of Samples to their closest Cluster Center (Centroid), Weighted by the Sample Weights (if provided)
'''
train_new_df=df_ppd[['Gender_code', 'Customer Type_code', 'Type of Travel_code', 'Class_code', 'satisfaction_code',
                         'Inflight wifi service_code', 'Departure/Arrival time convenient_code', 'Ease of Online booking_code',
                         'Gate location_code', 'Food and drink_code', 'Online boarding_code', 'Seat comfort_code',
                         'Inflight entertainment_code', 'On-board service_code', 'Leg room service_code',
                         'Baggage handling_code', 'Checkin service_code', 'Inflight service_code', 'Cleanliness_code','Departure Delay in Minutes', 'Arrival Delay in Minutes',  'Departure Delay in Minutes_mmnorm', 'Arrival Delay in Minutes_mmnorm']]
wcssd = [] # Within-Cluster-Sum-Squared-Distance
nr_clus = range(1,11) # Number of Clusters
for k in nr_clus:
    kmeans = kmclus(n_clusters=k, init='random', random_state=111)
    kmeans.fit(train_new_df)
    wcssd.append(kmeans.inertia_)
plt.plot(nr_clus, wcssd, marker='x')
plt.xlabel('Values of K')
plt.ylabel('Within Cluster Sum Squared Distance')
plt.title('Elbow Curve for Optimal K')
print(plt.show())


cluster_range = [2, 3, 4, 5]

# Iterate over different numbers of clusters
for k in cluster_range:
  # Perform Kmeans Clustering
    km_cluster = kmclus(n_clusters=k, init='random', random_state=222)
    print(km_cluster)
    km_cluster_model = km_cluster.fit_predict(train_new_df);
    print(km_cluster_model)
# Calculate Silhouette Score
    sscore_km_cluster = sscore(train_new_df, km_cluster_model);
    print(f"Silhouette Score for {k} clusters: {sscore_km_cluster}")
    # Calculate Davies-Bouldin Index
    dbscore_km_cluster = dbscore(train_new_df, km_cluster_model)
    print(f"Davies-Bouldin Index for {k} clusters: {dbscore_km_cluster}\n")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# None
# KMeans(init='random', n_clusters=2, random_state=222)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [1 1 1 ... 1 1 1]
# Silhouette Score for 2 clusters: 0.8454278741250736
# Davies-Bouldin Index for 2 clusters: 0.5026790910354849
#
# KMeans(init='random', n_clusters=3, random_state=222)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [2 2 2 ... 2 2 2]
# Silhouette Score for 3 clusters: 0.7785101017449825
# Davies-Bouldin Index for 3 clusters: 0.5635987128756391
#
# KMeans(init='random', n_clusters=4, random_state=222)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [2 2 2 ... 2 2 2]
# Silhouette Score for 4 clusters: 0.7319883613837083
# Davies-Bouldin Index for 4 clusters: 0.5651254033090566
#
# KMeans(init='random', n_clusters=5, random_state=222)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [1 2 2 ... 2 2 2]
# Silhouette Score for 5 clusters: 0.6794598176909962
# Davies-Bouldin Index for 5 clusters: 0.6062265959159291

# %%
import time
import psutil
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import seaborn as sns

# Start time
start_time = time.time()

# Specify the number of clusters
num_clusters = 4

# Initialize KMeans object
kmeans = KMeans(n_clusters=num_clusters, random_state=42)

# Fit KMeans clustering model to the data
kmeans.fit(train_new_df[['Gender_code', 'Customer Type_code', 'Type of Travel_code', 'Class_code', 'satisfaction_code',
                         'Inflight wifi service_code', 'Departure/Arrival time convenient_code', 'Ease of Online booking_code',
                         'Gate location_code', 'Food and drink_code', 'Online boarding_code', 'Seat comfort_code',
                         'Inflight entertainment_code', 'On-board service_code', 'Leg room service_code',
                         'Baggage handling_code', 'Checkin service_code', 'Inflight service_code', 'Cleanliness_code','Departure Delay in Minutes', 'Arrival Delay in Minutes',  'Departure Delay in Minutes_mmnorm', 'Arrival Delay in Minutes_mmnorm']])

# End time
end_time = time.time()

# Total time taken
time_taken = end_time - start_time
print("Time taken by K-Means for k=4:", "{:.4f} seconds".format(time_taken))

# Memory used by the KMeans model
memory_used = psutil.Process().memory_info().rss / 1024 / 1024  # Memory in MB
print("Memory used by K-Means for k=4:", "{:.2f} MB".format(memory_used))

# Get cluster labels
cluster_labels = kmeans.labels_

# Add cluster labels to DataFrame
train_new_df['cluster'] = cluster_labels

# Get centroids of each cluster
centroids = kmeans.cluster_centers_

# Visualize the clusters using seaborn
plt.figure(figsize=(10, 6))
sns.scatterplot(data=train_new_df, x='Departure Delay in Minutes', y='Arrival Delay in Minutes', hue='cluster', palette='viridis', s=100)
plt.scatter(centroids[:, 5], centroids[:, 6], marker='*', s=300, c='black', label='Centroids')
plt.xlabel('Departure delay in Minutes')
plt.ylabel('Arrival delay in Minutes')
plt.title('K-means Clustering with Centroids')
plt.legend(title='Cluster')
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Time taken by K-Means for k=4: 3.0426 seconds
# Memory used by K-Means for k=4: 519.45 MB
# <ipython-input-15-9fa61363fd29>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_new_df['cluster'] = cluster_labels

# %%
print(train_new_df)

# %%
# Further analysis or visualization with cluster labels

# Cluster Analysis with Categorical Variables: Chi-Square Test of Independence
# Assuming you have performed clustering and added cluster labels to your DataFrame 'df'

import pandas as pd
from scipy.stats import chi2_contingency

# Select categorical variables for analysis
categorical_variables = ['Gender_code', 'Customer Type_code', 'Type of Travel_code', 'Class_code', 'satisfaction_code',
                         'Inflight wifi service_code', 'Departure/Arrival time convenient_code', 'Ease of Online booking_code',
                         'Gate location_code', 'Food and drink_code', 'Online boarding_code', 'Seat comfort_code',
                         'Inflight entertainment_code', 'On-board service_code', 'Leg room service_code',
                         'Baggage handling_code', 'Checkin service_code', 'Inflight service_code', 'Cleanliness_code', 'cluster']

# Create a contingency table for each categorical variable and the cluster labels
contingency_tables = {}
for variable in categorical_variables:
    contingency_tables[variable] = pd.crosstab(train_new_df[variable], train_new_df['cluster'])

# Perform Chi-Square Test of Independence for each contingency table
chi2_results = {}
for variable, contingency_table in contingency_tables.items():
    chi2, p, dof, expected = chi2_contingency(contingency_table)
    chi2_results[variable] = {'Chi-Square': chi2, 'P-value': p}

# Display the results
for variable, result in chi2_results.items():
    print(f"Chi-Square Test of Independence for variable '{variable}':")
    print(f"   - Chi-Square Value: {result['Chi-Square']}")
    print(f"   - P-value: {result['P-value']}")
# Out:
# Chi-Square Test of Independence for variable 'Gender_code':
#    - Chi-Square Value: 0.9296547578575705
#    - P-value: 0.8182661719433676
# Chi-Square Test of Independence for variable 'Customer Type_code':
#    - Chi-Square Value: 1.459926797113409
#    - P-value: 0.6915495994417555
# Chi-Square Test of Independence for variable 'Type of Travel_code':
#    - Chi-Square Value: 1.0757750642818362
#    - P-value: 0.7829250614581827
# Chi-Square Test of Independence for variable 'Class_code':
#    - Chi-Square Value: 2.3791805601744564
#    - P-value: 0.8817366772728334
# Chi-Square Test of Independence for variable 'satisfaction_code':
#    - Chi-Square Value: 0.49896739538568585
#    - P-value: 0.9191182117567226
# Chi-Square Test of Independence for variable 'Inflight wifi service_code':
#    - Chi-Square Value: 17.41363166309483
#    - P-value: 0.2947445327494612
# Chi-Square Test of Independence for variable 'Departure/Arrival time convenient_code':
#    - Chi-Square Value: 13.145334619334733
#    - P-value: 0.5910733493451289
# Chi-Square Test of Independence for variable 'Ease of Online booking_code':
#    - Chi-Square Value: 18.092632924792618
#    - P-value: 0.2578268973825709
# Chi-Square Test of Independence for variable 'Gate location_code':
#    - Chi-Square Value: 12.61786480900276
#    - P-value: 0.6317872386856129
# Chi-Square Test of Independence for variable 'Food and drink_code':
#    - Chi-Square Value: 10.806085650514985
#    - P-value: 0.7662155827726429
# Chi-Square Test of Independence for variable 'Online boarding_code':
#    - Chi-Square Value: 14.208975375011438
#    - P-value: 0.5097426720000018
# Chi-Square Test of Independence for variable 'Seat comfort_code':
#    - Chi-Square Value: 12.531925727777987
#    - P-value: 0.6384018161405027
# Chi-Square Test of Independence for variable 'Inflight entertainment_code':
#    - Chi-Square Value: 7.4140811203244255
#    - P-value: 0.9451249192921461
# Chi-Square Test of Independence for variable 'On-board service_code':
#    - Chi-Square Value: 6.1839272019740905
#    - P-value: 0.9764897766012772
# Chi-Square Test of Independence for variable 'Leg room service_code':
#    - Chi-Square Value: 13.092378326743301
#    - P-value: 0.59516273683668
# Chi-Square Test of Independence for variable 'Baggage handling_code':
#    - Chi-Square Value: 9.03217912997935
#    - P-value: 0.7001794760081661
# Chi-Square Test of Independence for variable 'Checkin service_code':
#    - Chi-Square Value: 22.46458377579617
#    - P-value: 0.09618835444112203
# Chi-Square Test of Independence for variable 'Inflight service_code':
#    - Chi-Square Value: 7.074385451431943
#    - P-value: 0.9555526216388337
# Chi-Square Test of Independence for variable 'Cleanliness_code':
#    - Chi-Square Value: 8.283582201777087
#    - P-value: 0.9119108021810183
# Chi-Square Test of Independence for variable 'cluster':
#    - Chi-Square Value: 310782.0
#    - P-value: 0.0

# %%
from scipy.stats import f_oneway

# List of features for ANOVA
features = ['Departure Delay in Minutes', 'Arrival Delay in Minutes',  'Departure Delay in Minutes_mmnorm', 'Arrival Delay in Minutes_mmnorm']

# Initialize an empty dictionary to store ANOVA results
anova_results = {}

# Iterate over unique cluster labels
for cluster_label in train_new_df['cluster'].unique():
    # Filter dataframe for the current cluster
    cluster_df = train_new_df[train_new_df['cluster'] == cluster_label]

    # Initialize an empty dictionary to store ANOVA results for the current cluster
    cluster_anova_results = {}

    # Perform ANOVA for each feature
    for feature in features:
        # Perform ANOVA test
        anova_result = f_oneway(*[train_new_df[train_new_df['cluster'] == i][feature] for i in train_new_df['cluster'].unique()])
        # Store ANOVA result
        cluster_anova_results[feature] = anova_result

    # Store ANOVA results for the current cluster
    anova_results[cluster_label] = cluster_anova_results

# Print ANOVA results
for cluster_label, cluster_anova_result in anova_results.items():
    print(f"Cluster {cluster_label} ANOVA Results:")
    for feature, result in cluster_anova_result.items():
        print(f"{feature}: F-value = {result.statistic}, p-value = {result.pvalue}")
# Out:
# Cluster 0 ANOVA Results:
# Departure Delay in Minutes: F-value = 194101.06420857928, p-value = 0.0
# Arrival Delay in Minutes: F-value = 195911.21488670888, p-value = 0.0
# Departure Delay in Minutes_mmnorm: F-value = 0.4589713719625217, p-value = 0.7109555896515246
# Arrival Delay in Minutes_mmnorm: F-value = 0.8874999090411362, p-value = 0.4466414082685176
# Cluster 2 ANOVA Results:
# Departure Delay in Minutes: F-value = 194101.06420857928, p-value = 0.0
# Arrival Delay in Minutes: F-value = 195911.21488670888, p-value = 0.0
# Departure Delay in Minutes_mmnorm: F-value = 0.4589713719625217, p-value = 0.7109555896515246
# Arrival Delay in Minutes_mmnorm: F-value = 0.8874999090411362, p-value = 0.4466414082685176
# Cluster 1 ANOVA Results:
# Departure Delay in Minutes: F-value = 194101.06420857928, p-value = 0.0
# Arrival Delay in Minutes: F-value = 195911.21488670888, p-value = 0.0
# Departure Delay in Minutes_mmnorm: F-value = 0.4589713719625217, p-value = 0.7109555896515246
# Arrival Delay in Minutes_mmnorm: F-value = 0.8874999090411362, p-value = 0.4466414082685176
# Cluster 3 ANOVA Results:
# Departure Delay in Minutes: F-value = 194101.06420857928, p-value = 0.0
# Arrival Delay in Minutes: F-value = 195911.21488670888, p-value = 0.0
# Departure Delay in Minutes_mmnorm: F-value = 0.4589713719625217, p-value = 0.7109555896515246
# Arrival Delay in Minutes_mmnorm: F-value = 0.8874999090411362, p-value = 0.4466414082685176
